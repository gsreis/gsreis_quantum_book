# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.visualization import plot_bloch_multivector
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.circuit.library import *
from qiskit.visualization import plot_bloch_multivector
from qiskit.visualization import plot_bloch_vector
from qiskit_aer import Aer
from qiskit.visualization import plot_bloch_multivector
import math
from qiskit import qasm3
from qiskit.quantum_info import state_fidelity
from qiskit.quantum_info import DensityMatrix
from qiskit.visualization import plot_state_qsphere
from qiskit import transpile
from qiskit.visualization import plot_state_city, plot_histogram
from pylatexenc import *
from qiskit.quantum_info import Operator
from qiskit.quantum_info import Statevector
from qiskit import *
from qiskit.circuit import *
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.circuit.library import *
from qiskit.visualization import plot_bloch_multivector
from qiskit.visualization import plot_bloch_vector
from qiskit_aer import Aer
from qiskit.visualization import plot_bloch_multivector
import math
from qiskit import qasm3
from qiskit.quantum_info import state_fidelity
from qiskit.quantum_info import DensityMatrix
from qiskit import transpile
from qiskit.providers.basic_provider import BasicProvider
from qiskit_aer import AerSimulator

# %% [markdown]
# # Questão 1
#
# ![image](question1.png)

# %% [markdown]
# ## Resposta correta A, D
# ####  Resumo: A estrutura é {chave: valor, chave: valor} ou [{chave: valor, chave: valor},{chave: valor, chave: valor}]
# #### Pode ser fornecida um dicionário ou array de dicionários
# #### A chave pode ser númerica ou String
# #### Valor não pode ser array

# %%
from qiskit.visualization import plot_distribution
 
countsA = {0:500, 3:500} #OK
countsB = [(0,500),(3,500)] #ERRO
countsC = [0,1,2],[500,500,500] #ERRO
countsD = [{0:500, 3:500}, {0:500, 1:500}] #OK
countsE = {0: [300,500], 1: [400,500]} #ERRO (cada {} é uma coleção)
countsF = {'00': 525, '11': 499} #OK - chaves podem ser Strings
countsG = {'00': 511, '11': 514} 
# {F, G} - OK 
countsH = {0:[0,1,2], 1:[1,2,3]} #ERRO - Valor não podem ser ARRAYS

#A OK
plot_distribution(countsA, color=['crimson','midnightblue'],title="New Distribution")

#B ERRO, tuplas não aceitas
#plot_distribution(countsB, color=['crimson','midnightblue'],title="New Distribution")

#C ERRO, listas não aceitas
#plot_distribution(countsC, color=['crimson','midnightblue'],title="New Distribution")

#D - OK
#plot_distribution(countsD, color=['crimson','midnightblue'],title="New Distribution")

#E - ERRO
#plot_distribution(countsE, color=['crimson','midnightblue'],title="New Distribution")

#F - OK - Strings como chaves aceitas
#plot_distribution(countsF, color=['crimson','midnightblue'],title="New Distribution")

#G - OK - Arrays 
# values = [countsF, countsG]
# plot_distribution(values, color=['crimson','midnightblue'],title="New Distribution")

#H - ERRO - Valores não podem ser Strings
#plot_distribution(countsH, color=['crimson','midnightblue'],title="New Distribution")

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
#
# # Questão 2

# %% [markdown]
# ![image](question2.png)
# ## np.sqrt([1/2,1/2]) significa (1/sqrt(2), 1/sqrt(2)) ou hadamard
# ## A está errado porque [0.5, 0.5, 0.5] - equivale a [1/2X, 1/2Y, 1/2Z]
# ## B está correto pois [1,0,0] representa [X,0,0]
# ## C está errado pois [0,0,1] representa [0,0,Z]
# ## D está errado pois [0, np.sqrt(3.0)/2.0, 0] representa [0, np.sqrt(3.0)/2.0*Y, 0]
#
# # Lembrar que plot_bloch_vector([X,Y,Z])

# %%
import numpy as np
from qiskit import QuantumCircuit
import numpy as np

qc = QuantumCircuit(1) 
state_vector = np.sqrt([1/2, 1/2])
qc.initialize(state_vector, 0)
print(state_vector)
#plot_bloch_vector(qc)

#plot_bloch_vector([0.5, 0.5, 0.5])
plot_bloch_vector([1,0,0])
#plot_bloch_vector([0,0,1])
#value = [0, np.sqrt(3.0)/2.0, 0]
#print(value)
#plot_bloch_vector(value)
# Out:
# [0.70710678 0.70710678]

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Questão 3
# ![image](question3.png)
#
# # Resposta correta é B
# ## resumo - não existe método set, somente reset
# ## reset seguido de X torna o QUBIT |1>

# %%
qc = QuantumCircuit(1)
#A - ERRO não existe método SET
#qc.set(0)

#B - OK - reset e X geram |1>
qc.reset(0)
qc.x(0)

#C - ERRO - reset e H geram |+>
# qc.reset(0)
# qc.h(0)

#C - ERRO - não existe método set
# qc.reset(0)
# qc.h(0)

plot_bloch_multivector(qc)

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Questão 4
# ![image](question4.png)
#
# ## Resposta correta é D, todos os parâmetros são opcionais
# ##### Class for interacting with the Qiskit Runtime service.
# ##### jobs(limit=10, skip=0, backend_name=None, pending=None, program_id=None, instance=None, job_tags=None, session_id=None, created_after=None, created_before=None, descending=True) - Retrieve all runtime jobs, subject to optional filtering.
# ##### backends(name=None, min_num_qubits=None, instance=None, dynamic_circuits=None, filters=None, *, use_fractional_gates=False, **kwargs) - Return all backends accessible via this account, subject to optional filtering.
# ##### check_pending_jobs() - Check the number of pending jobs and wait for the oldest pending job if the maximum number of pending jobs has been reached.
# ##### static delete_account(filename=None, name=None, channel=None) - Delete a saved account from disk.
# ##### delete_job(job_id) - Delete a runtime job.
# ##### instances() - Return the instance list associated to the active account. For the “ibm_quantum” channel,
# ##### job(job_id) - Retrieve a runtime job.
# ##### least_busy(min_num_qubits=None, instance=None, filters=None, **kwargs) - Return the least busy available backend.
# ##### static save_account(token=None, url=None, instance=None, channel=None, filename=None, name=None, proxies=None, verify=None, overwrite=False, set_as_default=None, private_endpoint=False, region=None, plans_preference=None) - Save the account to disk for future use.
# ##### static saved_accounts(default=None, channel=None, filename=None, name=None) - List the accounts saved on disk.
# ##### usage() - Return monthly open plan usage information.

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Questão 5
# ![image](question5.png)
# # A resposta B é correta
# ![image](Fig88.png)

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Questão 6
# ![image](question6.png)
# # Resposta correta B

# %% [markdown]
# ### SparsePauliOp tem o método apply_layout (operator é do tipo SparsePauliOp)
# ### QuantumCircuit só tem o atributo layout para leitura - read only - (isa_circuit é do tipo QuantumCircuit)

# %%
from qiskit import QuantumCircuit 
from qiskit.quantum_info import SparsePauliOp
from qiskit_ibm_runtime import QiskitRuntimeService, EstimatorV2
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.providers.basic_provider import BasicProvider
from qiskit_ibm_runtime.options import EstimatorOptions

qreg = QuantumRegister(1, "qreg")
creg = QuantumRegister(1, "creg")
isa_circuit = QuantumCircuit(qreg, creg)
isa_circuit.rz(0,1)
isa_circuit.ecr(0,1)

options = EstimatorOptions(default_shots=4096)
backend = AerSimulator()
ZZ = SparsePauliOp(["ZZ"])
ZX = SparsePauliOp(["ZX"])
ops = [ZZ, ZX]

# A - ERRO
#isa_observables = [isa_circuit.layout(operator) for operator in ops]

#B - OK
isa_observables = [operator.apply_layout(isa_circuit.layout) for operator in ops]

#C - ERRO
#isa_observables = [operator(isa_circuit.layout) for operator in ops]

#D - ERRO
#isa_observables = [isa_circuit.set_layout(operator) for operator in ops]

pub = (isa_circuit, isa_observables)
estimator = EstimatorV2(mode=backend, options=options)
job = estimator.run([pub])
print(job.result())
# Out:
# PrimitiveResult([PubResult(data=DataBin(evs=np.ndarray(<shape=(2,), dtype=float64>), stds=np.ndarray(<shape=(2,), dtype=float64>), shape=(2,)), metadata={'target_precision': 0.015625, 'shots': 4096, 'circuit_metadata': {}})], metadata={'version': 2})

# %% [markdown]
# ### Parameterized SparsePauliOp does not support the following methods:
# ###        to_matrix(sparse=True) since scipy.sparse cannot have objects as elements.
# ###        to_operator() since Operator does not support objects.
# ###        sort, argsort since ParameterExpression does not support comparison.
# ###        equiv since ParameterExpression cannot be converted into complex.
# ###        chop since ParameterExpression does not support absolute value.
# ## SparsePauliOp(["II", "XZ"], np.array(ParameterVector("a", 2)))
# ## SparsePauliOp(['II', 'XZ'],
# ##      coeffs=[ParameterExpression(1.0*a[0]), ParameterExpression(1.0*a[1])])

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Explorar estimator

# %%
from qiskit.circuit import QuantumCircuit
from qiskit.quantum_info import SparsePauliOp
from qiskit_ibm_runtime import EstimatorV2
from qiskit_ibm_runtime.options import EstimatorOptions
from qiskit_aer import AerSimulator

circuit = QuantumCircuit(2)
circuit.h(0)
circuit.cx(0, 1)
backend = AerSimulator()
observables = SparsePauliOp("ZZ")
options = EstimatorOptions(default_shots=4096)
estimator = EstimatorV2(mode=backend, options=options) 
# For a non-parameterized circuit
pub1 = (circuit, observables)
# For a parameterized circuit with specific parameter values
circuit_param = QuantumCircuit(1)
param = Parameter('theta')
circuit_param.ry(param, 0)
observables_param = SparsePauliOp("Z")
pub2 = (circuit_param, observables_param, [3.14])
job = estimator.run([pub1]) # Or [pub1, pub2] for multiple PUBs
result = job.result()
expectation_value = result[0].data.evs
print(f"Expectation value: {expectation_value}")
# Out:
# Expectation value: 1.0

# %% [markdown]
# #### EstimatorV2 in Qiskit is a class designed for interacting with the Qiskit Runtime Estimator primitive service, which estimates expectation values of quantum circuits and observables. It is part of the qiskit_ibm_runtime library.
# #### The run() method of EstimatorV2 takes an iterable of "Primitive Unified Blocs" (PUBs). Each PUB is typically a tuple containing:
# #### A QuantumCircuit (possibly parameterized).
# #### One or more ObservablesArrayLike objects (e.g., Pauli, SparsePauliOp) representing the observables for which expectation values are estimated.
# #### Optional parameter_values for parameterized circuits.
# #### Optional precision, specifying the target precision for the expectation value estimates.

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Questão 7
# ![image](question7.png)

# %% [markdown]
# #### Initialize the account. Because Qiskit Runtime Estimator is a managed service, you first need to initialize your account. ...
# #### Create a circuit and an observable. ...
# #### Initialize Qiskit Runtime Estimator. ...
# #### Invoke the Estimator and get results.

# %% [markdown]
# #### Resposta correta
# #### 1 - Define quantum circuit and observable operator
# #### 2 - Transpile the circuit into the instruction Set Arqchitecture (ISA) and apply the layout to the observables
# #### 3 - Call the Estimator primitive
# #### 4 - Get primitive results
# ##### BaseEstimatorV2 is a primitive that estimates expectation values for provided quantum circuit and observable combinations.
# ##### Following construction, an estimator is used by calling its run() method with a list of pubs (Primitive Unified Blocs). Each pub contains three values that, together, define a computation unit of work for the estimator to complete:
# ##### a single QuantumCircuit, possibly parametrized, whose final state we define as
# ##### one or more observables (specified as any ObservablesArrayLike, including Pauli, SparsePauliOp, str) that specify which expectation values to estimate, denoted
# ##### a collection parameter value sets to bind the circuit against,
# ##### Running an estimator returns a BasePrimitiveJob object, where calling the method result() results in expectation value estimates and metadata for each pub:

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Questão 8
#
# ![image](question8.png)
#
# # Resposta correta B
#
# #### default_shots
# #### The default number of shots to use if none are specified in the PUBs or in the run method.
#
# #### The interface follows the style of the Qiskit V2 Primitives, which relies on PUBs. Each PUB is a tuple that contains a circuit and the data broadcasted to it. This greatly simplifies your ability to send complex data to a circuit. the run() method takes an array of PUBs.
#
# #### The interface follows the style of the Qiskit V2 Primitives, which relies on PUBs. Each PUB is a tuple that contains a circuit and the data broadcasted to it. This greatly simplifies your ability to send complex data to a circuit. the run() method takes an array of PUBs.
#
# #### The interface follows the style of the Qiskit V2 Primitives, which relies on PUBs. Each PUB is a tuple that contains a circuit and the data broadcasted to it. This greatly simplifies your ability to send complex data to a circuit. the run() method takes an array of PUBs.
#
# #### With the newest version of Qiskit Runtime, a requirement was introduced which makes it so that all circuits submitted to a backend must conform to the constraints of the backend’s Target. Such circuits are considered to be written in terms of that backend’s Instruction Set Architecture (ISA) — i.e., the set of instructions the device can understand and execute. These Target constraints are defined by factors like the device’s native basis gates, its qubit connectivity, and when relevant, its pulse and other instruction timing specifications.In this blog post, we’ll offer some quick and easy solutions for anyone running into this new ISA circuits error message, and explain the reasoning behind the change.

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Informação - Aprimorar capítulo Qiskit
#
# ## What is the Target?
# ### The Target object is primarily used within the qiskit.transpiler submodule. It contains all the important information a transpiler pass may need regarding the constraints of a particular backend. This includes items such as the basis gates of each qubit in the hardware, or the native direction of the available two-qubit gates.
# ### Most of the time, you don’t have to worry about the Target object when running your experiments, since it’s already an attribute of the BackendV2 you get when using the QiskitRuntimeService from Qiskit IBM Runtime. All backends on the IBM Quantum™ Platform have their own Target defined by default.
# ### Of course, this raises a key question: If the Target attribute of a backend contains all of the relevant information about the device’s available instructions, what information does the BackendV2 object of a device contain?
# ### The answer is that the BackendV2 provides the hooks to interact with the service or simulator for submitting primitive queries or looking up previous run jobs. It also allows users to request characterization data to model device behavior. In other words, the BackendV2 connects a Target to a service.
#
# ## What is PUB?
# ### In Qiskit, PUB stands for Primitive Unified Bloc. It's a data structure used as input for the Qiskit Primitives, specifically for the Sampler and Estimator. A PUB is essentially a tuple that contains a quantum circuit and associated data like parameter values or observables.
# ### PUBs enable broadcasting of data, allowing for efficient execution of circuits with varying parameter values or observables, as described in the Qiskit documentation on primitive inputs and outputs.
# ### In a Sampler's run() method, a list of PUBs is passed, where each PUB represents a circuit and its associated data. For instance, a list of tuples like [(circuit1, [0.1, 0.2]), (circuit2, [0.3])] would be a valid input, according to the MQT DDSIM documentation.
# ### The run() method of both Sampler and Estimator primitives accepts a list of PUBs as input, and returns a result based on the specified PUBs, according to the IBM Quantum documentation on primitive inputs and outputs.
#
# ## What is ISA
# ### With the newest version of Qiskit Runtime, a requirement was introduced which makes it so that all circuits submitted to a backend must conform to the constraints of the backend’s Target. Such circuits are considered to be written in terms of that backend’s Instruction Set Architecture (ISA) — i.e., the set of instructions the device can understand and execute. These Target constraints are defined by factors like the device’s native basis gates, its qubit connectivity, and when relevant, its pulse and other instruction timing specifications.
#
# ### Explorar no capitulo Qiskit
# ### Estimator
# ### Sampler - permite envio de vários circuitos para execução
# ### BackendV2 - O que já existia

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_ibm_runtime import QiskitRuntimeService, Sampler
from qiskit_ibm_runtime.fake_provider import FakeKyiv

# geral
creg = ClassicalRegister(1, "creg")
creg2 = ClassicalRegister(1, "creg2")
qreg = QuantumRegister(1, "qreg")
qreg2 = QuantumRegister(1, "qreg2")

qc = QuantumCircuit(qreg,creg)
qc2 = QuantumCircuit(qreg2,creg2)

qc.x(0)
qc2.x(0)

qc.measure_all()
qc2.measure_all()
backend = AerSimulator()

# USANDO SAMPLER
job = Sampler(backend).run([qc,qc2])
print(job.result())
print(job.result()[0].data.creg.get_counts())
print(job.result()[1].data.creg2.get_counts())


# USANDO Estimator
from qiskit.circuit.library import RealAmplitudes
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, EstimatorV2 as Estimator
from qiskit.circuit.library import real_amplitudes

backend = AerSimulator()
#psi = RealAmplitudes(num_qubits=2, reps=2)
psi = real_amplitudes(num_qubits=2, reps=2)
hamiltonian = SparsePauliOp.from_list([("II", 1), ("IZ", 2), ("XI", 3)])
theta = [0, 1, 1, 2, 3, 5]
pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_psi = pm.run(psi)
isa_observables = hamiltonian.apply_layout(isa_psi.layout)
estimator = Estimator(mode=backend)
# calculate [ <psi(theta1)|hamiltonian|psi(theta)> ]
job = estimator.run([(isa_psi, isa_observables, [theta])])
pub_result = job.result()[0].data.evs
print(pub_result)

#USANDO BACKEND.RUN()
# qc.measure_all()
# backend = BasicProvider().get_backend('basic_simulator')
# result = backend.run(qc, shots=256).result()
# counts = result.get_counts()
# print(counts)
# Out:
# [1.5703125]

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Questão 9
# ![image](question9.png)

# %% [markdown]
# ##  A resposta correta é job.result()[0].data.creg.get_counts() - C
# #### a resposta é um array de data com o objeto com mesmo nome de ClassicalRegisters, e chama-se o método get_count()
#
# ####  Sampler methods
# ####  run(pubs, *, shots=None)
# ####  Submit a request to the sampler primitive.
# ####  Parameters
# ####  pubs (Iterable[SamplerPubLike]) – An iterable of pub-like objects. For example, a list of circuits or tuples (circuit, parameter_values).
# ####  shots (int | None) – The total number of shots to sample for each sampler pub that does not specify its own shots. If None, the primitive’s default shots value will be used, which can vary by implementation.

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_ibm_runtime import QiskitRuntimeService, Sampler
from qiskit_ibm_runtime.fake_provider import FakeKyiv

qc = QuantumCircuit(3)
qreg = QuantumRegister(4, "qreg")
creg = ClassicalRegister(4, "creg")
qc = QuantumCircuit(qreg, creg)
qc.x(qreg)
qc.measure(qreg, creg)
backend = FakeKyiv()
job = Sampler(backend).run([qc])

#A - ERRO
# print(job.result(creg).to_counts_dict())

#B - ERRO
#print(job.get_counts(creg))

#C - OK 
print(job.result()[0].data.creg.get_counts())

#D - ERRO
#print(job.result().metadata.counts(creg))
# Out:
# {'1111': 988, '0111': 11, '1011': 15, '1101': 8, '1110': 2}

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 10

# %% [markdown]
# ![image](question10.png)
# # Resposta correta D

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

# 1. Save your IBM Quantum account credentials (one-time setup)
# Replace 'YOUR_IBM_QUANTUM_TOKEN' with your actual API token
# Replace 'YOUR_IBM_CLOUD_CRN' with your IBM Cloud Resource Name (CRN) if using ibm_cloud channel
QiskitRuntimeService.save_account(
    channel="ibm_cloud",  # or "ibm_cloud" for IBM Cloud accounts
    token="DEofJqdyhnwq9hKlPR0fZYZVuAcrx6d3zOAyQHkvRlgI",
    instance="crn:v1:bluemix:public:quantum-computing:us-east:a/ce20f97c55204afaa6ac7d0808acd5a6:6112df4b-3326-46cf-94f2-6e0328a06584::", # Uncomment and set if using ibm_cloud
    set_as_default=True,  # Set this account as the default for future sessions
    overwrite=True # Overwrite if an account is already saved
)

# 2. Instantiate the service (loads saved credentials by default)
service = QiskitRuntimeService()

# 3. List available backends
print("Available backends:")
for backend in service.backends():
    print(f"- {backend.name}")

# 4. Select a backend (e.g., a simulator or a real QPU)
# Replace 'simulator_statevector' with the name of your desired backend
backend = service.backend("ibm_torino") 

# 5. You can now use this 'backend' object to run Qiskit circuits
# For example, to run a simple circuit:
from qiskit import QuantumCircuit
from qiskit_ibm_runtime import Sampler

# Create a simple circuit
qc = QuantumCircuit(2, 2)
#qc.h(0)
#qc.cx(0, 1)
qc.measure([0, 1], [0, 1])

# Run the circuit using the Sampler primitive
job = Sampler(backend).run([qc])
print(job.result())
# with Sampler(session=service.session(backend=backend)) as sampler:
#     job = sampler.run(qc)
#     result = job.result()
#     print(f"Counts: {result.quasi_dists[0].binary_probabilities()}")
# Out:
# Available backends:
# - ibm_brisbane
# - ibm_torino
# PrimitiveResult([SamplerPubResult(data=DataBin(c=BitArray(<shape=(), num_shots=4096, num_bits=2>)), metadata={'circuit_metadata': {}})], metadata={'execution': {'execution_spans': ExecutionSpans([DoubleSliceSpan(<start='2025-08-08 17:05:54', stop='2025-08-08 17:05:56', size=4096>)])}, 'version': 2})

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 11

# %% [markdown]
# ![image](question11.png)

# %% [markdown]
# # Resposta correta D

# %%
from qiskit.quantum_info import Pauli
# A - ERRO - invertido quando X é primeiro
p = Pauli('-XX')
print(p.to_matrix())

# B - ERRO - invertido quando X é primeiro
p = Pauli('-XI')
print(p.to_matrix())

# C - ERRO - negativo gera -1
p = Pauli('-IX')
print(p.to_matrix())

#D - OK - Z gera negativo X no segundo sem efeito
p = Pauli('ZX')
print(p.to_matrix())
# Out:
# [[ 0.+0.j  0.+0.j  0.+0.j -1.+0.j]
#  [ 0.+0.j  0.+0.j -1.+0.j  0.+0.j]
#  [ 0.+0.j -1.+0.j  0.+0.j  0.+0.j]
#  [-1.+0.j  0.+0.j  0.+0.j  0.+0.j]]
# [[ 0.+0.j  0.+0.j -1.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j -1.+0.j]
#  [-1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j -1.+0.j  0.+0.j  0.+0.j]]
# [[ 0.+0.j -1.+0.j  0.+0.j  0.+0.j]
#  [-1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j -1.+0.j]
#  [ 0.+0.j  0.+0.j -1.+0.j  0.+0.j]]
# [[ 0.+0.j  1.+0.j  0.+0.j  0.+0.j]
#  [ 1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j -1.+0.j]
#  [ 0.+0.j  0.+0.j -1.+0.j  0.+0.j]]

# %%
from qiskit.quantum_info import Pauli
# X NA SEGUNDA POSICAO
p = Pauli('-XX')
print(p.to_matrix())

p = Pauli('IX')
print(p.to_matrix())

p = Pauli('YX')
print(p.to_matrix())

p = Pauli('ZX')
print(p.to_matrix())

p = Pauli('-IX')
print(p.to_matrix())
# Out:
# [[ 0.+0.j  0.+0.j  0.+0.j -1.+0.j]
#  [ 0.+0.j  0.+0.j -1.+0.j  0.+0.j]
#  [ 0.+0.j -1.+0.j  0.+0.j  0.+0.j]
#  [-1.+0.j  0.+0.j  0.+0.j  0.+0.j]]
# [[0.+0.j 1.+0.j 0.+0.j 0.+0.j]
#  [1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]]
# [[0.+0.j 0.+0.j 0.+0.j 0.-1.j]
#  [0.+0.j 0.+0.j 0.-1.j 0.+0.j]
#  [0.+0.j 0.+1.j 0.+0.j 0.+0.j]
#  [0.+1.j 0.+0.j 0.+0.j 0.+0.j]]
# [[ 0.+0.j  1.+0.j  0.+0.j  0.+0.j]
#  [ 1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j -1.+0.j]
#  [ 0.+0.j  0.+0.j -1.+0.j  0.+0.j]]
# [[ 0.+0.j -1.+0.j  0.+0.j  0.+0.j]
#  [-1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j -1.+0.j]
#  [ 0.+0.j  0.+0.j -1.+0.j  0.+0.j]]

# %% [markdown]
# ## Contar os QUBITS de trás para frente - Ex: Pauli("XYZ") X em q2, Y em q1 e Z em q0
# ### 1.	Se quadrante 1 e 4 sem valores e 2 e 3 preenchidos, existe X na primeira posição à esquerda
# ### 2.	Primeiro quadrante igual ao quarto quadrante, existe um I na primeira posição à esquerda
# ### 3.	Se aparecer a parcela imaginária (i, -i, j, -j) existe um Y na equação
# ### 4.	Mesmos valores com inversão de sinal, operador Z na primeira posição à esquerda
# ### 5.	Todos os valores negativos, indicativo de que há um sinal negativo
# ### 6.	Guardar as matrizes básicas para I, X, Y e Z
# ![image](pauli1.png)
# ![image](pauli2.png)
# ![image](pauli3.png)
# ![image](pauli4.png)
# ![image](pauli5.png)

# %% [markdown]
# #### In Qiskit's string representation of multi-qubit Paulis, the rightmost character corresponds to qubit 0, and the leftmost character corresponds to the highest-indexed qubit. Therefore, Pauli('XYZ') represents the tensor product, where: Z acts on qubit 0. Y acts on qubit 1. X acts on qubit 2.
# #### In essence, Pauli('XYZ') defines a three-qubit Pauli operator where a Pauli-Z gate is applied to the first qubit (qubit 0), a Pauli-Y gate to the second qubit (qubit 1), and a Pauli-X gate to the third qubit (qubit 2). This object can then be used in various Qiskit functionalities, such as defining Hamiltonians, constructing quantum circuits, or performing measurements in the Pauli basis.

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 12

# %% [markdown]
# ![image](question12.png)

# %% [markdown]
# # Resposta A e C
# #### Aceita valor numérico ou coleção de QuantumRegister e ClassicalRegister - Ambos aceitam número e String identificadora. O construtor aceita vários QuantumRegister e vários ClassicalRegister, mas todos os QuantumRegister precisam vir antes dos ClassicalRegister

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 13

# %% [markdown]
# ![image](question13.png)

# %% [markdown]
# # Reposta correta D e E
# #####  NÃO EXISTE if_else (o correto é if_test)
# ##### NÃO EXISTE switch_test (é somente switch)
# ##### NÃO EXISTE replace
# ##### while_loop OK
# ##### if_test OK
# #### while_loop OK

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 14

# %% [markdown]
# ![image](question14.png)

# %% [markdown]
# # Resposta correta D
# ## TwirlingOptions
# ####        enable_gates - Whether to apply 2-qubit Clifford gate twirling.
# ####        enable_measure - Whether to enable twirling to measurement instructions, as long as the measurement is not involved within a conditional block.
# #        num_randomizations - The number of random samples to use when twirling or peforming sampled mitigation.
# ####        shots_per_randomization - The number of shots to run for each random sample.
# ####        strategy ['active', 'active-accum', 'active-circuit', 'all']-Specify the strategy of twirling qubits in identified layers of 2-qubit twirled gates.

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 15

# %% [markdown]
# ![image](question15.png)
#
# # Resposta Correta B

# %%
import numpy as np 
from qiskit.circuit import Parameter
from qiskit import QuantumCircuit
from qiskit.primitives import StatevectorEstimator
from qiskit.quantum_info import SparsePauliOp

theta = Parameter('fi')
qc = QuantumCircuit(1)
qc.rx(theta, 0)
observable = SparsePauliOp.from_operator([[1,0],[0,-1]])
estimator = StatevectorEstimator()
param_values = np.array([0, np.pi/2, np.pi])
pub = (qc, observable, param_values)
job = estimator.run([pub])

measured_energy = job.result()[0]
print('estimator expectation val:', measured_energy)
# Out:
# estimator expectation val: PubResult(data=DataBin(evs=np.ndarray(<shape=(3,), dtype=float64>), stds=np.ndarray(<shape=(3,), dtype=float64>), shape=(3,)), metadata={'target_precision': 0.0, 'circuit_metadata': {}})

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 16

# %% [markdown]
# ![image](question16.png)

# %% [markdown]
# ### The interface follows the style of the Qiskit V2 Primitives, which relies on PUBs. Each PUB is a tuple that contains a circuit and the data broadcasted to it. This greatly simplifies your ability to send complex data to a circuit. the run() method takes an array of PUBs.
# # Resposta correta D

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 17

# %% [markdown]
# ![image](question17.png)

# %% [markdown]
# # Resposta correta C
# ### Pauli('Z') é identico ao qc.z(0)

# %%
from qiskit.quantum_info import Pauli

pauli_z = Pauli('Z')
print(pauli_z)

# Convert the Pauli Z operator to its matrix representation
matrix_z = pauli_z.to_matrix()
print("\nMatrix representation of Pauli Z:")
print(matrix_z)

# A ERRO @ não aceito 
# p = Pauli('Z'@Pauli('Y'))
# print(p)

# B ERRO - é PAuli('ZZ')
# b = Pauli('ZZ')
# print(b.to_matrix())

# C - OK
qc = QuantumCircuit(1)
qc.z(0)
p = Pauli(qc)
print(p.to_matrix())

# D - ERRO 
# v1 = [False]
# v2 = [True]
# p = Pauli((v1,v2))
# print(p.to_matrix())
# Out:
# Z
#
# Matrix representation of Pauli Z:
# [[ 1.+0.j  0.+0.j]
#  [ 0.+0.j -1.+0.j]]
# [[ 1.+0.j  0.+0.j]
#  [ 0.+0.j -1.+0.j]]

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 18

# %% [markdown]
# ![image](question18.png)

# %% [markdown]
# # Resposta correta C
# ### When making calls to the Qiskit Runtime REST API, include the generated bearer token in the Authorization header, formatted as Bearer <YOUR_BEARER_TOKEN>.

# %%
from qiskit_ibm_runtime import IBMRuntimeService

# Save an IBM Cloud account using the API key
IBMRuntimeService.save_account(auth="cloud", token="YOUR_IBM_CLOUD_API_KEY", instance="YOUR_IBM_CLOUD_CRN")

# Or, if you have a legacy IBM Quantum account token
IBMRuntimeService.save_account(auth="ibm_quantum", token="YOUR_IBM_QUANTUM_API_TOKEN")

# Initialize the service (authentication is handled automatically if saved)
service = IBMRuntimeService()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 from qiskit_ibm_runtime import IBMRuntimeService
#       3 # Save an IBM Cloud account using the API key
#       4 IBMRuntimeService.save_account(auth="cloud", token="YOUR_IBM_CLOUD_API_KEY", instance="YOUR_IBM_CLOUD_CRN")
#
# ImportError: cannot import name 'IBMRuntimeService' from 'qiskit_ibm_runtime' (/Users/glaucoreis/anaconda3/lib/python3.11/site-packages/qiskit_ibm_runtime/__init__.py)

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 19

# %% [markdown]
# ![image](question19.png)

# %% [markdown]
# # Resposta correta D

# %%
        # Assign a numeric value to 'theta'
        bound_qc_dict = qc.assign_parameters({theta: 1.57}) # Assign pi/2

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 20

# %% [markdown]
# ![image](question20.png)

# %% [markdown]
# # Resposta correta A (dump também é aceita, mas para file)

# %% [markdown]
# #### dump() para salvar em stream
# #### qasm3_string = dumps(qc)
# #### dumps aceita um file como segundo parâmetro ou o QuantumCircuit
# #### retorna a String se somente tiver um parâmetro

# %%
qiskit.qasm3.dumps(circuit, **kwargs)
# Serialize a QuantumCircuit object in an OpenQASM 3 string.


qiskit.qasm3.dump(circuit, stream, **kwargs)
# Serialize a QuantumCircuit object as an OpenQASM 3 stream to file-like object.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 qiskit.qasm3.dumps(circuit, **kwargs)
#       2 # Serialize a QuantumCircuit object in an OpenQASM 3 string.
#       5 qiskit.qasm3.dump(circuit, stream, **kwargs)
#
# NameError: name 'qiskit' is not defined

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 21

# %% [markdown]
# ![image](question21.png)

# %% [markdown]
# # Resposta correta B
# ## ParameterVector é como Parameter, mas permite armazenar mais valores
# ## resize(length)
# ## Resize the parameter vector. If necessary, new elements are generated.

# %%
from qiskit.circuit import ParameterVector, QuantumCircuit

# Create a ParameterVector named 'p' with 3 elements
p = ParameterVector('p', 3)

# Create a quantum circuit
circuit = QuantumCircuit(2)

# Apply a parameterized Rz gate to qubit 0 using p[0]
circuit.rz(p[0], 0)

# Apply a parameterized Rx gate to qubit 1 using p[1]
circuit.rx(p[1], 1)

# Apply a parameterized CNOT gate using p[2] as a phase parameter
# (Note: not all gates directly accept parameters in this way, this is illustrative)
circuit.crz(p[2], 0, 1)

# You can then assign values to these parameters:
assigned_circuit = circuit.assign_parameters({p: [1.0, 0.5, 2.0]})

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 22

# %% [markdown]
# ![image](question22.png)

# %% [markdown]
# # Resposta correta D
# ### The number of jobs running in parallel is based on the degree of parallelism configured for the backend, which is five for most backends. However, the number of concurrent jobs in an active batch could be lower because there could be other jobs already running when the batch becomes active.

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 23

# %% [markdown]
# ![image](question23.png)

# %% [markdown]
# # Resposta correta C

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 24

# %% [markdown]
# ![image](question24.png)

# %% [markdown]
# # Resposta correta B

# %%
qc = QuantumCircuit(1)
qc.reset(0)
qc.rx(np.pi, 0)
state = Statevector.from_instruction(qc)
plot_bloch_multivector(state)

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 25

# %% [markdown]
# ![image](question25.png)

# %% [markdown]
# # Resposta correta B
# ##### 0b111 é igual a 7 - O while_loop vai executar 7 vezes o measure. A resposta terá 7 valores

# %%
from qiskit.circuit import QuantumCircuit, QuantumRegister, ClassicalRegister
qubits = QuantumRegister(3, 'q')
clbits = ClassicalRegister(3, 'c')
circuit = QuantumCircuit(qubits,clbits)
circuit.h([0,1,2])
circuit.measure([0,1,2],[0,1,2])
with circuit.while_loop((clbits, 0b111)):
    circuit.h([0,1,2])
    circuit.measure([0,1,2],[0,1,2])
#backend = BasicProvider().get_backend('basic_simulator')
backend = AerSimulator()
result = backend.run(circuit, shots=256).result()
counts = result.get_counts()
print(counts)
# Out:
# {'011': 36, '101': 32, '001': 32, '100': 31, '110': 34, '010': 40, '000': 51}

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 26

# %% [markdown]
# ![image](question26.png)

# %% [markdown]
# # respostas corretas A e C
# #### DYNAMICAL DECOUPLING
# #### Quantum circuits are executed on IBM® hardware as sequences of microwave pulses that need to be scheduled and run at precise time intervals. Unfortunately, unwanted interactions between qubits can lead to coherent errors on idling qubits. Dynamical decoupling works by inserting pulse sequences on idling qubits to approximately cancel out the effect of these errors.
# ### Pauli twirling
# #### Twirling, also known as randomized compiling, is a widely used technique for converting arbitrary noise channels into noise channels with more specific structure.
# #### Pauli twirling is a special kind of twirling that uses Pauli operations. It has the effect of transforming any quantum channel into a Pauli channel. Performed alone, it can mitigate coherent noise because coherent noise tends to accumulate quadratically with the number of operations, whereas Pauli noise accumulates linearly.
# ### Twirled readout error extinction (TREX)
# #### Twirled readout error extinction (TREX) mitigates the effect of measurement errors for the estimation of Pauli observable expectation values. It is based on the notion of twirled measurements, which are accomplished by randomly substituting measurement gates by a sequence of (1) a Pauli X gate, (2) a measurement, and (3) classical bit flip.
# ### Zero-noise extrapolation (ZNE)
# #### Zero-noise extrapolation (ZNE) is a technique for mitigating errors in estimating expectation values of observables. While it often improves results, it is not guaranteed to produce an unbiased result.
# #### ZNE consists of two stages:
# #### Noise amplification: The original quantum circuit is executed multiple times at different noise rates.
# #### Extrapolation: The ideal result is estimated by extrapolating the noisy expectation value results to the zero-noise limit.
# ### Probabilistic Error Amplification (PEA)
# #### One of the main challenges in ZNE is to accurately amplify the noise affecting the target circuit. Gate folding provides an easy way to perform this amplification, but is potentially inaccurate and might lead to incorrect results. See the article "Scalable error mitigation for noisy quantum circuits produces competitive expectation values", and specifically page 4 of the supplementary information for details. Probabilistic error amplification provides a more accurate approach to error amplification through noise learning.
# ### Probabilistic error cancellation (PEC)
# #### Probabilistic error cancellation (PEC) is a technique for mitigating errors in estimating expectation values of observables. Unlike ZNE, it returns an unbiased estimate of the expectation value. However, it generally incurs a greater overhead.

# %%
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_ibm_runtime import QiskitRuntimeService
 
service = QiskitRuntimeService()
backend = service.least_busy()

#DYNAMICAL DECOUPLING
estimator = Estimator(mode=backend)
estimator.options.dynamical_decoupling.enable = True
estimator.options.dynamical_decoupling.sequence_type = "XpXm"

#Pauli twirling
estimator = Estimator(mode=backend)
estimator.options.twirling.enable_gates = True
estimator.options.twirling.num_randomizations = 32
estimator.options.twirling.shots_per_randomization = 100

#Twirled readout error extinction (TREX)
estimator = Estimator(mode=backend)
estimator.options.resilience.measure_mitigation = True
estimator.options.resilience.measure_noise_learning.num_randomizations = 32
estimator.options.resilience.measure_noise_learning.shots_per_randomization = 100

#Zero-noise extrapolation (ZNE)
estimator = Estimator(mode=backend)
estimator.options.resilience.zne_mitigation = True
estimator.options.resilience.zne.noise_factors = (1, 3, 5)
estimator.options.resilience.zne.extrapolator = "exponential"

#Probabilistic Error Amplification (PEA)
estimator = Estimator(mode=backend)
estimator.options.resilience.zne_mitigation = True
estimator.options.resilience.zne.amplifier = "pea"

#Probabilistic error cancellation (PEC)
estimator = Estimator(mode=backend)
estimator.options.resilience.pec_mitigation = True
estimator.options.resilience.pec.max_overhead = 100

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 27

# %% [markdown]
# ![image](question27.png)

# %% [markdown]
# # Resposta correta A

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 28

# %% [markdown]
# ![image](question28.png)

# %% [markdown]
# # Resposta correta A

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 29

# %% [markdown]
# ![image](question29.png)

# %% [markdown]
# # Resposta correta D
#
# ### The available resilience_level options and their corresponding effects are:
# ### 0: No mitigation.
# ###         No error mitigation techniques are applied. This provides the fastest execution but is most susceptible to noise.
# ### 1: Minimal mitigation costs.
# ###        This level primarily focuses on mitigating readout errors, which are errors that occur when measuring the final state of qubits.
# ### 2: Medium mitigation costs.
# ###        This level typically employs more advanced error mitigation techniques, such as Zero Noise Extrapolation (ZNE), which aims to reduce bias in estimator results. While it can improve accuracy, it is not guaranteed to eliminate all bias.

# %% [markdown]
# #Zero-noise extrapolation (ZNE)
# estimator = Estimator(mode=backend)
# estimator.options.resilience.zne_mitigation = True
# estimator.options.resilience.zne.noise_factors = (1, 3, 5)
# estimator.options.resilience.zne.extrapolator = "exponential"

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 30

# %% [markdown]
# ![image](question30.png)

# %% [markdown]
# # Resposta correta B

# %%
p = Pauli('X')
print(p.to_matrix())
# Out:
# [[0.+0.j 1.+0.j]
#  [1.+0.j 0.+0.j]]

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 31

# %% [markdown]
# ![image](question31.png)

# %% [markdown]
# # Resposta correta C, D, E
#
# #### a single QuantumCircuit, possibly parametrized, whose final state we define as
# #### one or more observables (specified as any ObservablesArrayLike, including Pauli, SparsePauliOp, str) that specify which expectation values to estimate, denoted
# #### a collection parameter value sets to bind the circuit against,
# #### an optional target precision for expectation value estimates.
# #### max_execution_time (UnsetType | int)
# #### environment (EnvironmentOptions | Dict)
# #### simulator (SimulatorOptions | Dict)
# #### default_precision (UnsetType | float)
# #### default_shots (UnsetType | int | None)
# #### resilience_level (UnsetType | int)
# #### seed_estimator (UnsetType | int)
# #### dynamical_decoupling (DynamicalDecouplingOptions | Dict)
# #### resilience (ResilienceOptionsV2 | Dict)
# #### execution (ExecutionOptionsV2 | Dict)
# #### twirling (TwirlingOptions | Dict)
# #### experimental (UnsetType | dict)

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 32

# %% [markdown]
# ![image](question32.png)

# %% [markdown]
# # Resposta correta B

# %%
from qiskit.circuit.random import random_circuit
qc = random_circuit(32,32)
# A ERR - não existe método
#qc = qc.unroll3qOrMore()

# B - OK sem erros
from qiskit.transpiler import PassManager
from qiskit.transpiler.passes import Unroll3qOrMore
pass_manager = PassManager([Unroll3qOrMore()])
qc= pass_manager.run(qc)

#C - missing required parameter state
# from qiskit.transpiler.passes import Unroll3qOrMore
# qc = Unroll3qOrMore().execute(qc)

#D - 'QuantumCircuit' object has no attribute 'apply_pass'
# from qiskit.transpiler.passes import Unroll3qOrMore
# qc.apply_pass(Unroll3qOrMore())

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 33

# %% [markdown]
# ![image](question33.png)

# %% [markdown]
# # Resposta correta D

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 34

# %% [markdown]
# ![image](question34.png)

# %% [markdown]
# # Resposta correta D

# %% [markdown]
# #### Example 1: (broadcast single observable) has a parameter value set that is a 5x1 array and a 1x1 observables array. The one item in the observables array is combined with each item in the parameter value set to create a single 5x1 array where each item is a combination of the original item in the parameter value set with the item in the observables array.
#
# #### Example 2: (zip) has a 5x1 parameter value set and a 5x1 observables array. The output is a 5x1 array where each item is a combination of the nth item in the parameter value set with the nth item in the observables array.
#
# #### Example 3: (outer/product) has a 1x6 parameter value set and a 4x1 observables array. Their combination results in a 4x6 array that is created by combining each item in the parameter value set with every item in the observables array, and thus each parameter value becomes an entire column in the output.
#
# #### Example 4: (Standard nd generalization) has a 3x6 parameter value set array and two 3x1 observables array. These combine to create two 3x6 output arrays in a similar manner to the previous example.

# %% [markdown]
# ![image](visual.png)

# %% [markdown]
# #### When invoking a primitive's run() method, the main argument that is required is a list of one or more tuples -- one for each circuit being executed by the primitive. Each of these tuples is considered a PUB, and the required elements of each tuple in the list depends on the primitive used. The data provided to these tuples can also be arranged in a variety of shapes to provide flexibility in a workload through broadcasting -- the rules of which are described in a following section.
#
# ## For the Estimator primitive, the format of the PUB should contain at most four values:
#
# #### A single QuantumCircuit, which may contain one or more Parameter objects
# #### A list of one or more observables, which specify the expectation values to estimate, arranged into an array (for example, a single observable represented as a 0-d array, a list of observables as a 1-d array, and so on). The data can be in any one of the ObservablesArrayLike format such as Pauli, SparsePauliOp, PauliList, or str.
# #### A collection of parameter values to bind the circuit against. This can be specified as a single array-like object where the last index is over circuit Parameter objects, or omitted (or equivalently, set to None) if the circuit has no Parameter objects.
# #### (Optionally) a target precision for expectation values to estimate
#
# ## For the Sampler primitive, the format of the PUB tuple contains at most three values:
#
# #### A single QuantumCircuit, which may contain one or more Parameter objects Note: These circuits should also include measurement instructions for each of the qubits to be sampled.
# #### A collection of parameter values to bind the circuit against
# ####   (only needed if any Parameter objects are used that must be bound at runtime)
# #### (Optionally) a number of shots to measure the circuit with

# %% [markdown]
# ### Parameter value sets are represented by n x m arrays, and observable arrays are represented by one or more single-column arrays. For each example in the previous code, the parameter value sets are combined with their observable array to create the resulting expectation value estimates.
#
# ### Example 1: (broadcast single observable) has a parameter value set that is a 5x1 array and a 1x1 observables array. The one item in the observables array is combined with each item in the parameter value set to create a single 5x1 array where each item is a combination of the original item in the parameter value set with the item in the observables array.
#
# ### Example 2: (zip) has a 5x1 parameter value set and a 5x1 observables array. The output is a 5x1 array where each item is a combination of the nth item in the parameter value set with the nth item in the observables array.
#
# ### Example 3: (outer/product) has a 1x6 parameter value set and a 4x1 observables array. Their combination results in a 4x6 array that is created by combining each item in the parameter value set with every item in the observables array, and thus each parameter value becomes an entire column in the output.
#
# ### Example 4: (Standard nd generalization) has a 3x6 parameter value set array and two 3x1 observables array. These combine to create two 3x6 output arrays in a similar manner to the previous example.

# %%
from qiskit.circuit import (
    Parameter,
    QuantumCircuit,
    ClassicalRegister,
    QuantumRegister,
)
from qiskit.transpiler import generate_preset_pass_manager
from qiskit.quantum_info import SparsePauliOp
from qiskit.primitives.containers import BitArray
 
from qiskit_ibm_runtime import (
    QiskitRuntimeService,
    EstimatorV2 as Estimator,
    SamplerV2 as Sampler,
)
 
import numpy as np
 
# Instantiate runtime service and get
# the least busy backend
service = QiskitRuntimeService()
backend = service.least_busy(operational=True, simulator=False)
 
# Define a circuit with two parameters.
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.cx(0, 1)
circuit.ry(Parameter("a"), 0)
circuit.rz(Parameter("b"), 0)
circuit.cx(0, 1)
circuit.h(0)
 
# Transpile the circuit
pm = generate_preset_pass_manager(optimization_level=1, backend=backend)
transpiled_circuit = pm.run(circuit)
layout = transpiled_circuit.layout
 
# Now define a sweep over parameter values, the last axis of dimension 2 is
# for the two parameters "a" and "b"
params = np.vstack(
    [
        np.linspace(-np.pi, np.pi, 100),
        np.linspace(-4 * np.pi, 4 * np.pi, 100),
    ]
).T
 
# Define three observables. The inner length-1 lists cause this array of
# observables to have shape (3, 1), rather than shape (3,) if they were
# omitted.
observables = [
    [SparsePauliOp(["XX", "IY"], [0.5, 0.5])],
    [SparsePauliOp("XX")],
    [SparsePauliOp("IY")],
]
# Apply the same layout as the transpiled circuit.
observables = [
    [observable.apply_layout(layout) for observable in observable_set]
    for observable_set in observables
]
 
# Estimate the expectation value for all 300 combinations of observables
# and parameter values, where the pub result will have shape (3, 100).
#
# This shape is due to our array of parameter bindings having shape
# (100, 2), combined with our array of observables having shape (3, 1).
estimator_pub = (transpiled_circuit, observables, params)
 
# Instantiate the new estimator object, then run the transpiled circuit
# using the set of parameters and observables.
estimator = Estimator(mode=backend)
job = estimator.run([estimator_pub])
result = job.result()

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 35

# %% [markdown]
# ![image](question35.png)

# %% [markdown]
# # Resposta correta D

# %% [markdown]
# ### 1. What is Dynamical Decoupling?
# ### Dynamical decoupling involves applying a series of carefully timed pulses (e.g., X or Y rotations) to a qubit during idle periods in a quantum circuit. These pulses are designed to suppress the effects of noise, such as dephasing, by effectively "canceling out" the system-environment interaction.
# ### 2. Why use Dynamical Decoupling in Qiskit?
# ### Mitigates Decoherence:
# ### DD helps to reduce the impact of decoherence, which is the loss of quantum information due to interactions with the environment.
# ### Improves Circuit Performance:
# ### By suppressing decoherence, DD can lead to more accurate results in quantum computations.
# ### Effective for Idle Periods:
# ### DD is particularly useful when a circuit has idle time for some qubits, where noise has more time to act.

# %%
from qiskit.transpiler import generate_preset_pass_manager
from qiskit.circuit.library import efficient_su2
 
qc = efficient_su2(12, entanglement="circular", reps=1)
pm = generate_preset_pass_manager(1, target=target, seed_transpiler=12345)
qc_t = pm.run(qc)
qc_t.draw("mpl", fold=-1, idle_wires=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 5
#       2 from qiskit.circuit.library import efficient_su2
#       4 qc = efficient_su2(12, entanglement="circular", reps=1)
# ----> 5 pm = generate_preset_pass_manager(1, target=target, seed_transpiler=12345)
#       6 qc_t = pm.run(qc)
#       7 qc_t.draw("mpl", fold=-1, idle_wires=False)
#
# NameError: name 'target' is not defined

# %% [markdown]
# ![image](dinamicdecoupling.png)

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 36

# %% [markdown]
# ![image](question36.png)

# %% [markdown]
# # Resposta correta D
# ### PUBs enable broadcasting of data, allowing for efficient execution of circuits with varying parameter values or observables, as described in the Qiskit documentation on primitive inputs and outputs.¶

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 37

# %% [markdown]
# ![image](question37.png)

# %% [markdown]
# # Resposta correta A
# #### To monitor jobs in Qiskit, particularly within a Qiskit Runtime session, you need to track the job's status using its job_id. You can retrieve a list of your submitted jobs and their corresponding IDs, and then use the QiskitRuntimeService.job() method to access individual job details, including its status.

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 38

# %% [markdown]
# ![image](question38.png)

# %% [markdown]
# # Resposta correta C
#
# #### run(pubs, *, shots=None)
# #### Submit a request to the sampler primitive.
# ### Parameters
# ## pubs (Iterable[SamplerPubLike]) – An iterable of pub-like objects. For example, a list of circuits or tuples (circuit, parameter_values).
# #### shots (int | None) – The total number of shots to sample for each sampler pub that does not specify its own shots. If None, the primitive’s default shots value will be used, which can vary by implementation.

# %% [markdown]
# #### USANDO SAMPLER
# #### job = Sampler(backend).run([qc,qc2])
# ####  print(job.result())
# #### print(job.result()[0].data.creg.get_counts())
# #### print(job.result()[1].data.creg2.get_counts())

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 39

# %% [markdown]
# ![image](question39.png)

# %% [markdown]
# # Resposta correta D (mais próximo do |0>)

# %%
qc = QuantumCircuit(1)
qc.reset(0)
qc.rx(np.pi / 4, 0)
matrix = Statevector.from_instruction(qc)
plot_bloch_multivector(matrix, figsize=[3,3])

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 40

# %% [markdown]
# ![image](question40.png)

# %% [markdown]
# # Resposta correta A

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 41

# %% [markdown]
# ![image](question41.png)

# %% [markdown]
# # Resposta correta D

# %%
# A - ERRO
# qc = QuantumCircuit(2)
# qc.h(0)
# qc.cx(0,1)
# state = Statevector(qc)
# plot_state_qsphere(state)

# B - Erro
# qc = QuantumCircuit(2)
# qc.x(0)
# qc.x(1)
# qc.h(0)
# qc.cx(0,1)
# state = Statevector(qc)
# plot_state_qsphere(state)

# C - ERRO
qc = QuantumCircuit(2)
qc.x(1)
qc.h(0)
qc.cx(0,1)
state = Statevector(qc)
plot_state_qsphere(state)

# D - OK
qc = QuantumCircuit(2)
qc.h(0)
qc.z(0)
qc.cx(0,1)
state = Statevector(qc)
plot_state_qsphere(state)

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 42

# %% [markdown]
# ![image](question42.png)

# %% [markdown]
# # Resposta correta D
# #### index(value)
# #### Find the index of a ParameterVectorElement within the list.
# #### It is typically much faster to use the ParameterVectorElement.index property.
#
# #### resize(length)
# #### Resize the parameter vector. If necessary, new elements are generated.

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 43

# %% [markdown]
# ![image](question43.png)

# %% [markdown]
# # Resposta correta C

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 44

# %% [markdown]
# ![image](question44.png)

# %% [markdown]
# # Resposta correta B

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 45

# %% [markdown]
# ![image](question45.png)

# %% [markdown]
# # Resposta correta A
# #### The observables and parameter values portion of a pub can be array-valued with arbitrary dimensions, where standard broadcasting rules are applied, so that, in turn, the estimated result for each pub is in general array-valued as well. For more information, please check here.

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 46

# %% [markdown]
# ![image](question46.png)

# %% [markdown]
# # Resposta correta B
# #### In Qiskit Runtime, "twirling" refers to an error mitigation technique where random Clifford gates are inserted into a quantum circuit to make the noise more uniform and easier to handle. The TwirlingOptions class in qiskit-ibm-runtime provides several options for controlling how twirling is applied. These options determine which qubits and gates are twirled, and the extent of the twirling process.
# #### 1. enable_gates: This boolean option enables or disables Pauli twirling for gates. When set to True, it activates twirling, and when set to False, it disables it.
# ### 2. enable_measure: This boolean option enables or disables twirling of measurements. It only applies to measurement registers not involved in conditional logic. It's True by default for Estimator and False for Sampler.
# #### 3. num_randomizations: This integer option specifies the number of circuit instances to sample from the twirled ensemble. A higher number of randomizations generally leads to a more accurate mitigation, but it also increases the runtime.
# #### 4. shots_per_randomization: This integer option sets the number of shots to sample from each circuit instance during the twirling process. This value is used in conjunction with num_randomizations to determine the total number of shots taken.

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 47

# %% [markdown]
# ![image](question47.png)

# %% [markdown]
# # Resposta correta A

# %%
qubits = QuantumRegister(1, 'q')
clbits = ClassicalRegister(1, 'c')
circuit = QuantumCircuit(qubits,clbits)
circuit.h(qubits)
circuit.measure(qubits, clbits)
with circuit.switch(clbits) as case: 
    with case(0):
        circuit.x(qubits)
    with case(1):
        circuit.z(qubits)
circuit.measure(qubits, clbits)
circuit.draw(output='mpl')

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 48

# %% [markdown]
# ![image](question48.png)

# %% [markdown]
# #### Accessing Expectation Values (EVs): The result object returned by job.result() for an Estimator job contains the estimated expectation values. For EstimatorV2, the expectation values are typically found within the data.evs attribute of the result object, which is usually a list if multiple pubs (Primitive Unified Blocks) were submitted.

# %% [markdown]
# # Resposta correta B

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_ibm_runtime import QiskitRuntimeService, Sampler
from qiskit_ibm_runtime.fake_provider import FakeKyiv
from qiskit.circuit.library import real_amplitudes
# geral
creg = ClassicalRegister(3, "creg")
qreg = QuantumRegister(3, "qreg")
qc = QuantumCircuit(qreg,creg)
qc.x(0)
qc.measure_all()
backend = AerSimulator()
# USANDO Estimator
from qiskit.circuit.library import RealAmplitudes
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, EstimatorV2 as Estimator
backend = AerSimulator()
psi = real_amplitudes(num_qubits=3, reps=2)
hamiltonian = SparsePauliOp.from_list([("III", 1), ("XXX", 2), ("YYY", 3), ("ZZZ", 4), ("XYZ", 5)])
theta = [0, 1, 1, 2, 3, 5, 6, 7, 8]
pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_psi = pm.run(psi)
isa_observables = hamiltonian.apply_layout(isa_psi.layout)
job =  Estimator(mode=backend).run([(isa_psi, isa_observables, [theta])])
pub_result = job.result()[0].data.evs
print(pub_result.shape)
print(job.result()[0])
# Out:
# (1,)
# PubResult(data=DataBin(evs=np.ndarray(<shape=(1,), dtype=float64>), stds=np.ndarray(<shape=(1,), dtype=float64>), shape=(1,)), metadata={'target_precision': 0.015625, 'shots': 4096, 'circuit_metadata': {}})

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 49

# %% [markdown]
# ![image](question49.png)

# %% [markdown]
# # Resposta correta D (somente os measure importam no problema)

# %%
qubits = QuantumRegister(3)
clbits = ClassicalRegister(3)
qc = QuantumCircuit(qubits, clbits)
vector = [np.sqrt(0.2), np.sqrt(0.8)]
qc.initialize(vector, 0)
qc.barrier()
qc.h(1)
qc.cx(1,2)
qc.cx(0,1)
qc.h(0)
qc.barrier()

#A - ERRO - não existe if
# with qc.if((clbits[0],1)):
#     qc.z(2)
# with qc.if((clbits[0],1)):
#     qc.x(2)  
# qc.measure(qubits, clbits)

#B - ERRO - não existe if
# with qc.if((clbits[0],1)):
#     qc.x(2)
# qc.measure(0,0)
# with qc.if((clbits[0],1)):
#     qc.z(2)  
# qc.measure(qubits, clbits)

#C - OK
# qc.measure(0,0)
# with qc.if_test((clbits[1],1)):
#     qc.x(2)
# qc.measure(1,1)
# with qc.if_test((clbits[0],1)):
#     qc.z(2)  
# qc.measure(qubits[2], clbits[2])

qc.measure(0,0)
with qc.if_test((clbits[1],1)):
    qc.z(2)
qc.measure(1,1)
with qc.if_test((clbits[0],1)):
    qc.z(2)  
qc.measure(qubits[2], clbits[2])

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 50

# %% [markdown]
# ![image](question50.png)

# %% [markdown]
# # Resposta correta B
# #### In Qiskit's string representation of multi-qubit Paulis, the rightmost character corresponds to qubit 0, and the leftmost character corresponds to the highest-indexed qubit. Therefore, Pauli('XYZ') represents the tensor product, where: Z acts on qubit 0. Y acts on qubit 1. X acts on qubit 2.
# #### In essence, Pauli('XYZ') defines a three-qubit Pauli operator where a Pauli-Z gate is applied to the first qubit (qubit 0), a Pauli-Y gate to the second qubit (qubit 1), and a Pauli-X gate to the third qubit (qubit 2). This object can then be used in various Qiskit functionalities, such as defining Hamiltonians, constructing quantum circuits, or performing measurements in the Pauli basis.

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 51

# %% [markdown]
# ![image](question51.png)

# %% [markdown]
# # Resposta correta C

# %%
qc = QuantumCircuit(2)
qc.x(0)
qc.cx(0,1)
matrix = Statevector.from_instruction(qc)
plot_bloch_multivector(matrix, figsize=[3,3])

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 52

# %% [markdown]
# ![image](question52.png)

# %% [markdown]
# # Resposta correta D

# %%
from qiskit.circuit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import Session, SamplerV2 as Sampler
 
service = QiskitRuntimeService()
backend = service.least_busy(operational=True, simulator=False)
 
# Bell Circuit
qr = QuantumRegister(2, name="qr")
cr = ClassicalRegister(2, name="cr")
qc = QuantumCircuit(qr, cr, name="bell")
qc.h(qr[0])
qc.cx(qr[0], qr[1])
qc.measure(qr, cr)
 
backend = AerSimulator()

with Session(backend=backend) as session:
    sampler = Sampler(mode=session)
    job = sampler.run([isa_circuit])
    pub_result = job.result()[0]
    print(f"Sampler job ID: {job.job_id()}")
    print(f"Counts: {pub_result.data.cr.get_counts()}")
    sampler = Sampler(mode=session)
    job = sampler.run([isa_circuit])
    pub_result = job.result()[0]
    print(f"Sampler job ID: {job.job_id()}")
    print(f"Counts: {pub_result.data.cr.get_counts()}")
# Out:
# Sampler job ID: 3f6218c3-b748-4b76-8c8b-630b6d3b3878
# Counts: {'00': 495, '11': 529}
# Sampler job ID: fdbf16bd-f473-4fd1-ba2a-b21ec5108bf4
# Counts: {'11': 526, '00': 498}

# %% [markdown]
# #### A Qiskit Runtime session allows you to group a collection of iterative calls to the quantum computer.
# ## A session is started when the first job within the session is started.
# #### Subsequent jobs within the session are prioritized by the scheduler.
# #### Sem limite de submissões por Session (código acima)

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 53

# %% [markdown]
# ![image](question53.png)

# %% [markdown]
# ## Resposta correta C
# #### (3 rotações em Z geram -Z - rotação em X e Y em sequência geram |0>) - lembre-se de que X e Y funcionam como inversores

# %%
qc = QuantumCircuit(1)
qc.x(0)
qc.y(0)
qc.z(0)
qc.z(0)
qc.x(0)
qc.y(0)
qc.z(0)
p = Pauli(qc)
print(p.to_matrix())
# matrix = Statevector.from_instruction(qc)
# plot_bloch_multivector(matrix, figsize=[3,3])

#A - ERRADO
#print(Pauli('-Y').to_matrix())


#B - ERRADO

#C - OK - 3 rotações em Z causam -Z
print(Pauli('-Z').to_matrix())

# D - ERRO dois componentes negativos
#print(Pauli('-I').to_matrix())
# Out:
# [[-1.+0.j  0.+0.j]
#  [ 0.+0.j  1.-0.j]]
# [[-1.+0.j  0.+0.j]
#  [ 0.+0.j  1.-0.j]]

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 54

# %% [markdown]
# ![image](question54.png)

# %% [markdown]
# # Resposta correta C

# %% [markdown]
# #### Session constructor.
# #### Parameters
# ###        backend (BackendV2) – Instance of Backend class.
# ####        max_time (Optional[Union[int, str]]) – Maximum amount of time, a runtime session can be open before being forcibly closed. Can be specified as seconds (int) or a string like “2h 30m 40s”. This value must be less than the system imposed maximum.
# ####        create_new (Optional[bool]) – If True, the POST session API endpoint will be called to create a new session. Prevents creating a new session when from_id() is called.

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 55

# %% [markdown]
# ![image](question55.png)

# %% [markdown]
# # Respostas corretas B, C, D

# %% [markdown]
# ## Session usage is the time from when the first job starts until the session goes inactive, is closed, or when its last job completes, whichever happens last.
# ## Batch usage is the amount of time all jobs spend on the QPU.
# #### Return session usage in seconds.
# #### Close the session so new jobs will no longer be accepted, but existing queued or running jobs will run to completion. The session will be terminated once there are no more pending jobs.
#
# ## details()
# #### Return session details.
# #### A dictionary with the sessions details.
# #### id: id of the session.
# #### backend_name: backend used for the session.
# #### interactive_timeout: The maximum idle time (in seconds) between jobs that is allowed to occur before the session is deactivated.
# #### max_time: Maximum allowed time (in seconds) for the session, subject to plan limits.
# #### active_timeout: The maximum time (in seconds) a session can stay active.
# #### state: State of the session - open, active, inactive, or closed.
# #### accepting_jobs: Whether or not the session is accepting jobs.
# #### last_job_started: Timestamp of when the last job in the session started.
# #### last_job_completed: Timestamp of when the last job in the session completed.
# #### started_at: Timestamp of when the session was started.
# #### closed_at: Timestamp of when the session was closed.
# #### activated_at: Timestamp of when the session state was changed to active.
# #### mode: Execution mode of the session.
# ### usage_time: The usage time, in seconds, of this Session or Batch. Usage is defined as the time a quantum system is committed to complete a job.

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 56

# %% [markdown]
# ![image](question56.png)

# %% [markdown]
# # Resposta correta B
# #### noise_factors são valores para amplificação, não podem ser negativos
# #### são sequence de tuplas, não pode ser A nem D

# %% [markdown]
# #### noise_factors()
# #### Noise factors to use for noise amplification.
# #### Default: (1, 1.5, 2) for PEA, and (1, 3, 5) otherwise.
#
# #### amplifier
# #### Which technique to use for amplifying noise.
# #### “gate_folding” (default) uses 2-qubit gate folding to amplify noise. If the noise
# #### factor requires amplifying only a subset of the gates, then these gates are chosen randomly.
#
# #### “gate_folding_front” uses 2-qubit gate folding to amplify noise. If the noise
# #### factor requires amplifying only a subset of the gates, then these gates are selected from the front of the topologically ordered DAG circuit.
#
# #### “gate_folding_back” uses 2-qubit gate folding to amplify noise. If the noise
# #### factor requires amplifying only a subset of the gates, then these gates are selected from the back of the topologically ordered DAG circuit.
#
# #### “pea” uses a technique called Probabilistic Error Amplification
# #### (PEA) to amplify noise. When this option is selected, gate twirling will always be used whether or not it has been enabled in the options. In this technique, the twirled noise model of each each unique layer of entangling gates in your ISA circuits is learned beforehand, see LayerNoiseLearningOptions for relevant learning options. Once complete, your circuits are executed at each noise factor, where every entangling layer of your circuits is amplified by probabilistically injecting single-qubit noise proportional to the corresponding learned noise model.
#
# #### extrapolator
# #### 'linear',
# #### 'exponential',
# #### 'double_exponential',
# #### 'polynomial_degree_1',
# #### 'polynomial_degree_2',
# #### 'polynomial_degree_3',
# #### 'polynomial_degree_4',
# #### 'polynomial_degree_5',
# #### 'polynomial_degree_6',
# #### 'polynomial_degree_7',
# #### 'fallback'

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 57

# %% [markdown]
# ![image](question57.png)

# %% [markdown]
# # Resposta correta A

# %% [markdown]
# #### TdgGate
# #### Single qubit T-adjoint gate (~Z**0.25).
# #### It induces a −π/4 phase.

# %%
qc = QuantumCircuit(1)
qc.x(0)
qc.tdg(0)
# matrix = Statevector.from_instruction(qc)
# plot_bloch_multivector(matrix, figsize=[3,3])
# state = Statevector(qc)
# plot_state_qsphere(state)

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 58

# %% [markdown]
# ![image](question58.png)

# %% [markdown]
# # Resposta correta B

# %% [markdown]
# #### Pauli twirling is a technique used in quantum computing to transform arbitrary noise channels into Pauli channels, which are simpler to handle. It works by randomly applying Pauli operations (X, Y, Z, I) to a quantum system and averaging the results, effectively "twirling" the noise into a more manageable form. This simplification can make it easier to mitigate errors and improve the performance of quantum algorithms.
# #### Pauli twirling addresses this by applying random Pauli operations before and after a quantum gate. By averaging the results over many such twirled circuits, the overall noise channel can be transformed into a Pauli channel.
# #### Twirling, also known as randomized compiling , is a widely used technique for converting arbitrary noise channels into noise channels with more specific structure. Pauli twirling is a special kind of twirling that uses Pauli operations. It has the effect of transforming any quantum channel into a Pauli channel.
#
# #### Pauli twirling is a special kind of twirling that uses Pauli operations. It has the effect of transforming any quantum channel into a Pauli channel. Performed alone, it can mitigate coherent noise because coherent noise tends to accumulate quadratically with the number of operations, whereas Pauli noise accumulates linearly. Pauli twirling is often combined with other error mitigation techniques that work better with Pauli noise than with arbitrary noise.
#
# #### Pauli twirling is implemented by sandwiching a chosen set of gates with randomly chosen single-qubit Pauli gates in such a way that the ideal effect of the gate remains the same. The result is that a single circuit is replaced with a random ensemble of circuits, all with the same ideal effect. When sampling the circuit, samples are drawn from multiple random instances, rather than just a single one.
#
#
# #### num_randomizations: The number of circuit instances to draw from the ensemble of twirled circuits.
# #### shots_per_randomization: The number of shots to sample from each circuit instance.
# #### The following code cell shows how to enable Pauli twirling and set these options for the estimator. None of these options are required to be set explicitly.

# %%
estimator = Estimator(mode=backend)
estimator.options.twirling.enable_gates = True
estimator.options.twirling.num_randomizations = 32
estimator.options.twirling.shots_per_randomization = 100

# %% [markdown]
# # Outras tecnicas
#
# Twirled readout error extinction (TREX)
# Twirled readout error extinction (TREX) mitigates the effect of measurement errors for the estimation of Pauli observable expectation values. It is based on the notion of twirled measurements, which are accomplished by randomly substituting measurement gates by a sequence of (1) a Pauli X gate, (2) a measurement, and (3) classical bit flip. Just like in standard gate twirling, this sequence is equivalent to a plain measurement in the absence of noise, as depicted in the following diagram:
#
# In the presence of readout error, measurement twirling has the effect of diagonalizing the readout-error transfer matrix, making it easy to invert. Estimating the readout-error transfer matrix requires executing additional calibration circuits, which introduces a small overhead.
#
# TREX can be enabled by setting measure_mitigation to True in the Qiskit Runtime resilience options for Estimator. Options for measurement noise learning are described here. As with gate twirling, you can set the number of circuit randomizations and the number of shots per randomization.
#
# The following code cell shows how to enable TREX and set these options for the estimator. None of these options are required to be set explicitly.

# %%
estimator = Estimator(mode=backend)
estimator.options.resilience.measure_mitigation = True
estimator.options.resilience.measure_noise_learning.num_randomizations = 32
estimator.options.resilience.measure_noise_learning.shots_per_randomization = 100

# %% [markdown]
# Zero-noise extrapolation (ZNE)
# Zero-noise extrapolation (ZNE) is a technique for mitigating errors in estimating expectation values of observables. While it often improves results, it is not guaranteed to produce an unbiased result.
#
# ZNE consists of two stages:
#
# Noise amplification: The original quantum circuit is executed multiple times at different noise rates.
# Extrapolation: The ideal result is estimated by extrapolating the noisy expectation value results to the zero-noise limit.
# Both the noise amplification and extrapolation stages can be implemented in many different ways. Qiskit Runtime implements noise amplification by "digital gate folding," which means that two-qubit gates are replaced with equivalent sequences of the gate and its inverse. For example, replacing a unitary
#  U would yield a noise amplification factor of 3. For the extrapolation, you can choose from one of several functional forms, including a linear fit or an exponential fit. The image below depicts digital gate folding on the left, and the extrapolation procedure on the right.
#
# ZNE can be enabled by setting zne_mitigation to True in the Qiskit Runtime resilience options for Estimator. The Qiskit Runtime options for ZNE are described here. The following options are notable:
#
# noise_factors: The noise factors to use for noise amplification.
# extrapolator: The functional form to use for the extrapolation.
# The following code cell shows how to enable ZNE and set these options for the estimator. None of these options are required to be set explicitly.

# %%
estimator = Estimator(mode=backend)
estimator.options.resilience.zne_mitigation = True
estimator.options.resilience.zne.noise_factors = (1, 3, 5)
estimator.options.resilience.zne.extrapolator = "exponential"

# %% [markdown]
# Probabilistic Error Amplification (PEA)
# One of the main challenges in ZNE is to accurately amplify the noise affecting the target circuit. Gate folding provides an easy way to perform this amplification, but is potentially inaccurate and might lead to incorrect results. See the article "Scalable error mitigation for noisy quantum circuits produces competitive expectation values", and specifically page 4 of the supplementary information for details. Probabilistic error amplification provides a more accurate approach to error amplification through noise learning.
#
# PEA is a more sophisticated technique that performs preliminary experiments to reconstruct the noise and then uses this information to perform an accurate amplification. It starts by learning the twirled noise model of each layer of entangling gates in the circuit before they are run (see LayerNoiseLearningOptions for relevant learning options). After the learning phase, the circuits are executed at each noise factor, where every entangling layer of the circuits is amplified by probabilistically injecting single-qubit noise proportional to the corresponding learned noise model. See the article "Evidence for the utility of quantum computing before fault tolerance" for more details.
#
# PEA consists of three stages:
#
# Learning: The twirled noise model of each layer of entangling gates in the circuit is learned.
# Noise amplification: The original quantum circuit is executed multiple times at different noise factors.
# Extrapolation: The ideal result is estimated by extrapolating the noisy expectation value results to the zero-noise limit.
# For utility-scale experiments, PEA is often the best choice.
#
# Because PEA is a ZNE noise amplification technique, you also need to enable ZNE by setting resilience.zne_mitigation = True. Other resilience.zne options can additionally be used to set extrapolators, amplification levels, and so on. PEA requires a noise model, which is automatically generated when using primitives.
#
# The following snippet provides an example where PEA is used to mitigate the result of an Estimator job:

# %%
estimator = Estimator(mode=backend)
estimator.options.resilience.zne_mitigation = True
estimator.options.resilience.zne.amplifier = "pea"

# %% [markdown]
# Probabilistic error cancellation (PEC)
# Probabilistic error cancellation (PEC) is a technique for mitigating errors in estimating expectation values of observables. Unlike ZNE, it returns an unbiased estimate of the expectation value. However, it generally incurs a greater overhead.
#
# In PEC, the effect of an ideal target circuit is expressed as a linear combination of noisy circuits that are actually implementable in practice:
#
# The output of the ideal circuit can then be reproduced by executing different noisy circuit instances drawn from a random ensemble defined by the linear combination. If the coefficients
#
#   form a probability distribution, they can be used directly as the probabilities of the ensemble. In practice, some of the coefficients are negative, so they form a quasi-probability distribution instead. They can still be used to define a random ensemble, but there is a sampling overhead related to the negativity of the quasi-probability distribution, which is characterized by the quantity
#
#
# The sampling overhead is a multiplicative factor on the number of shots required to estimate an expectation value to a given precision, compared to the number of shots that would be needed from the ideal circuit. It scales quadratically with
# γ, which in turn scales exponentially with the depth of the circuit.
#
# PEC can be enabled by setting pec_mitigation to True in the Qiskit Runtime resilience options for Estimator. The Qiskit Runtime options for PEC are described here. A limit on the sampling overhead can be set using the max_overhead option. Note that limiting the sampling overhead can cause the precision of the result to exceed the requested precision. The default value of max_overhead is 100.
#
# The following code cell shows how to enable PEC and set the max_overhead option for the estimator.

# %%
estimator = Estimator(mode=backend)
estimator.options.resilience.pec_mitigation = True
estimator.options.resilience.pec.max_overhead = 100

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 59

# %% [markdown]
# ![image](question59.png)

# %% [markdown]
# # Resposta correta A

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 60

# %% [markdown]
# ![image](question60.png)

# %% [markdown]
# # Resposta correta D

# %%
from qiskit import QuantumCircuit
from qiskit import generate_preset_pass_manager
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0,1)
pass_manager = generate_preset_pass_manager(
    optimization_level=3,
    basis_gates={ "ecr", "rz", "sx", "x" }
)
tqc = pass_manager.run(qc)
tqc.draw(output="mpl", idle_wires=False)

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 61

# %% [markdown]
# ![image](question61.png)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_ibm_runtime import QiskitRuntimeService, Sampler
from qiskit_ibm_runtime.fake_provider import FakeKyiv
from qiskit.circuit.library import RealAmplitudes
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, EstimatorV2 as Estimator
from qiskit.circuit.library import RealAmplitudes
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, EstimatorV2 as Estimator


qc = QuantumCircuit(3,3)
qc.x(0)
qc.measure_all()
backend = AerSimulator()
job = Sampler(backend).run([qc])
print(job.result()[0].data.meas.get_bitstrings()[0:100])
# Out:
# ['001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001', '001']

# %% [markdown]
# # Resposta correta D

# %% [markdown]
# ####  Estimator V2 continues to return expectation values.
# #### The data portion of a Estimator V2 PubResult contains both expectation values and standard errors (stds). V1 returned variance in metadata.
# #### Sampler V2 returns per-shot measurements in the form of bitstrings, instead of the quasi-probability distributions from the V1 interface. The bitstrings show the measurement outcomes, preserving the shot order in which they were measured.
# #### Sampler V2 has convenience methods like get_counts() to help with migration.
# #### The Sampler V2 result objects organize data in terms of their input circuits' classical register names, for compatibility with dynamic circuits. By default, the classical register name is meas, as shown in the following example. When defining your circuit, if you create one or more classical registers with a non-default name, use that name to get the results. You can find the classical register name by running <circuit_name>.cregs. For example, qc.cregs.

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 62

# %% [markdown]
# ![image](question62.png)

# %% [markdown]
# # Resposta correta D

# %% [markdown]
# #### When working with Qiskit and IBM Quantum jobs, if a job fails or encounters an error, the error_message() method of the IBMQJob object can be used to retrieve details about the error.
# #### Obtain the IBMQJob object: This object is returned when a quantum circuit or program is submitted to an IBM Quantum backend.

# %%
from qiskit import QuantumCircuit

backend = AerSimulator()
qc = QuantumCircuit(1, 1)
qc.measure(0, 0)
job = backend.run(qc)
print(job.status())
if job.status().name == 'ERROR':
    error_info = job.error_message()
    print(f"Job error: {error_info}")
# Out:
# JobStatus.INITIALIZING

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 63

# %% [markdown]
# ![image](question63.png)

# %% [markdown]
# # Resposta correta A

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 64

# %% [markdown]
# ![image](question64.png)

# %% [markdown]
# # Resposta correta C

# %%
from qiskit.circuit.library import RealAmplitudes
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, EstimatorV2 as Estimator
from qiskit.circuit.library import real_amplitudes 
service = QiskitRuntimeService()
backend = service.least_busy(operational=True, simulator=False)
 
psi = real_amplitudes(num_qubits=2, reps=2)
hamiltonian = SparsePauliOp.from_list([("II", 1), ("IZ", 2), ("XI", 3)])
theta = [0, 1, 1, 2, 3, 5]
 
pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_psi = pm.run(psi)
isa_observables = hamiltonian.apply_layout(isa_psi.layout)
 
estimator = Estimator(mode=backend)
 
# calculate [ <psi(theta1)|hamiltonian|psi(theta)> ]
job = estimator.run([(isa_psi, isa_observables, [theta])])
pub_result = job.result()[0]
print(f"Expectation values: {pub_result.data.evs}")
# Out:
# Expectation values: [1.56807787]

# %% [markdown]
# #### Following construction, an estimator is used by calling its run() method with a list of PUBs (Primitive Unified Blocs). Each PUB contains four values that, together, define a computation unit of work for the estimator to complete:
# #### a single QuantumCircuit, possibly parametrized, whose final state we define as
# #### one or more observables (specified as any ObservablesArrayLike, including Pauli, SparsePauliOp, str) that specify which expectation values to estimate, denoted
# #### a collection parameter value sets to bind the circuit against,
# #### an optional target precision for expectation value estimates.
# #### Initializes the Estimator primitive.
# #### Parameters
# #### mode (Optional[Union[BackendV2, Session, Batch, str]]) –
# #### The execution mode used to make the primitive query. It can be:
# #### A Backend if you are using job mode.
# #### A Session if you are using session execution mode.
# #### A Batch if you are using batch execution mode.

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 65

# %% [markdown]
# ![image](question65.png)

# %% [markdown]
# # Resposta correta B

# %% [markdown]
# #### Dynamic circuits are powerful tools that give us the ability to measure qubits in the middle of a quantum circuit execution, and then perform classical logical operations within the circuit based on the outcome of those mid-circuit measurements. All of this occurs in the blink of an eye, before the circuit execution is complete, allowing us to take creative approaches to solving problems with quantum computation. These capabilities will be essential for the modular quantum computing architectures and quantum error correction protocols of the future. However, we still have a lot of work to do to explore their full potential.
# #### Initialize a circuit with 1 qubit and 2 classical bits. ( q0, b0, and b1 )
# #### Apply a Hadamard gate to q0
# #### Measure that qubit and save the result in b0
# #### Begin an if_test block conditioned on b0 being equal to 1.
# #### In the if_test block, specify the operation to do if the condition is met, in this case, flipping q0 to 0 state.
# #### Measure q0 again into b1 to check that we always get 0.

# %%
from qiskit import * 
qubits = QuantumRegister(1)
clbits = ClassicalRegister(1)

#A - OK - mas não tem measure no meio
# circuit = QuantumCircuit(qubits, clbits)
# circuit.h(0)
# with circuit.if_test((clbits[0], 1)):
#     circuit.x(qubits[0])
    
# B - OK DynamicCircuit permitem medir no meio do processamento, e continuar executando o circuito
circuit = QuantumCircuit(qubits, clbits)
circuit.h(qubits[0])
circuit.measure(qubits[0], clbits[0])
with circuit.if_test((clbits[0], 1)):
    circuit.x(qubits[0])

# C - ERRO não existem DynamicCircuits
# circuit = DynamicCircuit(qubits, clbits)
# circuit.h(qubits[0])
# circuit.measure(qubits[0], clbits[0])
# with circuit.if_test((clbits[0], 1)):
#     circuit.x(qubits[0])

# D - ERRO DynamicCircuits e test não existem 
# circuit = QuantumCircuit(qubits, clbits)
# circuit.h(qubits[0])
# circuit.measure(qubits[0], clbits[0])
# with circuit.test((clbits[0], 1)):
#     circuit.x(qubits[0])

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 66

# %% [markdown]
# ![image](question66.png)

# %% [markdown]
# # Resposta correta B
# #### mode (Optional[Union[BackendV2, Session, Batch]]) –
# #### The execution mode used to make the primitive query. It can be:
# #### A Backend if you are using job mode.
# #### A Session if you are using session execution mode.
# #### A Batch if you are using batch execution mode.

# %%
# Execução modo batch
from qiskit_ibm_runtime import (
    QiskitRuntimeService,
    Batch,
    SamplerV2 as Sampler,
    EstimatorV2 as Estimator,
)
service = QiskitRuntimeService()
backend = service.least_busy(operational=True, simulator=False)
batch = Batch(backend=backend)
estimator = Estimator(mode=batch)
sampler = Sampler(mode=batch)
batch.close()

# %%
# Execução modo session
from qiskit_ibm_runtime import (
    QiskitRuntimeService,
    Batch, Session, 
    SamplerV2 as Sampler,
    EstimatorV2 as Estimator,
)
service = QiskitRuntimeService()
backend = service.least_busy(operational=True, simulator=False)
session = Session(backend=backend)
estimator = Estimator(mode=session)
sampler = Sampler(mode=session)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/qiskit_ibm_runtime/api/session.py:328, in RetrySession.request(self, method, url, bare, **kwargs)
#     327     response = super().request(method, final_url, headers=headers, **kwargs)
# --> 328     response.raise_for_status()
#     329 except RequestException as ex:
#     330     # Wrap the requests exceptions into a IBM Q custom one, for
#     331     # compatibility.
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://us-east.quantum-computing.cloud.ibm.com/sessions
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Execução modo backend
from qiskit_ibm_runtime import (
    QiskitRuntimeService,
    Batch, Session, 
    SamplerV2 as Sampler,
    EstimatorV2 as Estimator,
)
service = QiskitRuntimeService()
backend = service.least_busy(operational=True, simulator=False)
estimator = Estimator(mode=backend)
sampler = Sampler(mode=backend)

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 67

# %% [markdown]
# ![image](question67.png)

# %% [markdown]
# # Resposta correta D

# %% [markdown]
# #### The execution modes determine how your jobs are scheduled, and choosing the right execution mode allows your workload to run efficiently within your budget. There are three execution modes: job, session, and batch.

# %% [markdown]
# #### To limit processing time in Qiskit, particularly when using Qiskit Runtime, you can set a maximum execution time using the max_execution_time parameter when submitting a job. This parameter, measured in seconds, specifies the maximum quantum time a job can run before being forcibly canceled. You can also limit the overall execution time of a batch or session using the max_time parameter.

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit_ibm_runtime import EstimatorV2 as Estimator
 
service = QiskitRuntimeService()
backend = service.least_busy(operational=True, simulator=False)
 
estimator = Estimator(mode=backend)
 
estimator.options.max_execution_time = 2500

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------
# # QUESTAO 68

# %% [markdown]
# ![image](question68.png)

# %% [markdown]
# # Resposta correta D

# %% [markdown]
# #### The run() can be used to submit circuits, observables, and parameters to the Estimator primitive.
# #### Following construction, an estimator is used by calling its run() method with a list of PUBs (Primitive Unified Blocs). Each PUB contains four values that, together, define a computation unit of work for the estimator to complete:
# #### a single QuantumCircuit, possibly parametrized, whose final state we define as
# #### one or more observables (specified as any ObservablesArrayLike, including Pauli, SparsePauliOp, str) that specify which expectation values to estimate, denoted
# #### a collection parameter value sets to bind the circuit against,
# #### an optional target precision for expectation value estimates.
# #### Here is an example of how the estimator is used.

# %%
from qiskit.circuit.library import RealAmplitudes
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, EstimatorV2 as Estimator
from qiskit.circuit.library import real_amplitudes

service = QiskitRuntimeService()
backend = service.least_busy(operational=True, simulator=False)
 
psi = real_amplitudes(num_qubits=2, reps=2)
hamiltonian = SparsePauliOp.from_list([("II", 1), ("IZ", 2), ("XI", 3)])
theta = [0, 1, 1, 2, 3, 5]
 
pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_psi = pm.run(psi)
isa_observables = hamiltonian.apply_layout(isa_psi.layout)
 
estimator = Estimator(mode=backend)
 
job = estimator.run([(isa_psi, isa_observables, [theta])])
pub_result = job.result()[0]
print(f"Expectation values: {pub_result.data.evs}")
# Out:
# Expectation values: [1.52031088]
