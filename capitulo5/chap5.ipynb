# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.circuit.library import *
from qiskit.visualization import plot_bloch_multivector
from qiskit.visualization import plot_bloch_vector
from qiskit_aer import Aer
from qiskit.visualization import plot_bloch_multivector
import math
from qiskit import qasm3
from qiskit.quantum_info import state_fidelity
from qiskit.quantum_info import DensityMatrix
from qiskit.visualization import plot_state_qsphere
from qiskit import transpile
from qiskit.visualization import plot_state_city, plot_histogram
from pylatexenc import *
from qiskit.quantum_info import Operator
from qiskit.quantum_info import Statevector
from qiskit import *
from qiskit.circuit import *

# %%
from qiskit.qasm3 import *
from qiskit.qasm3 import dumps

qc = QuantumCircuit(5)
# qc.x(0)
# qc.y(0)
# qc.z(0)
# qc.rx(math.pi, 0)
# qc.ry(math.pi, 0)
# qc.rz(math.pi, 0)
# qc.reset(0)
# qc.h(0)
# qc.s(0)
# qc.t(0)
# qc.tdg(0)
# qc.sdg(0)
# qc.u(math.pi,math.pi,math.pi,0)
# qc.r(math.pi,math.pi,0)
# qc.p(math.pi,0)
# qc.sx(0)
# qc.sxdg(0)

qc.cx(1,2)
qc.cy(1,2)
qc.cz(1,2)
qc.crx(math.pi, 1, 2)
qc.cry(math.pi, 1, 2)
qc.crz(math.pi, 1, 2)
qc.rxx(math.pi/2,2,3)
qc.ryy(math.pi/2,2,3)
qc.rzx(math.pi/2,2,3)
qc.rzz(math.pi/2,2,3)
qc.ccx(0,1,2)
qc.ccz(0,1,2)
qc.cs(0,1)
qc.csx(0,1)
qc.csdg(0,1)
qc.dcx(0,1)
qc.cp(math.pi,0,1)
qc.cu(math.pi,math.pi,math.pi,math.pi,0,1)
qc.ch(0,1)
qc.cswap(0,1,2)
qc.iswap(0,1)
qc.swap(0,1)
qc.mcp(math.pi,[0,1],2)
qc.mcrx(math.pi,[0,1],2)
qc.mcry(math.pi,[0,1],2)
qc.mcrz(math.pi,[0,1],2)
qc.mcx([0,1],2)
qc.ecr(0,1)
qc.rv(math.pi/2,math.pi/2,math.pi/2,0)
qc.rccx(0,1,2)
qc.rcccx(0,1,2,3)
qc.ms(math.pi/2,[0,1])

#print(dumps(qc))
qc.draw(output='mpl', style={'backgroundcolor': '#EEEEEE'})
#display(Operator.from_circuit(qc).draw("latex"))
#qc.decompose().draw(output='mpl', style={'backgroundcolor': '#EEEEEE'})

# %%
from qiskit.providers.basic_provider import BasicSimulator 
from qiskit import QuantumCircuit

circ = QuantumCircuit(1)
circ.h(0)
circ.measure_all()

simulator = BasicSimulator()
result = simulator.run(circ, shots=5000).result()
counts= result.get_counts()
print(counts)
circ.draw(output='mpl', style={'backgroundcolor': '#EEEEEE'})

# %%
from qiskit.qasm3 import *
from qiskit.qasm3 import dumps

qc = QuantumCircuit(1)
qc.ry(math.pi, 0)
qc.draw(output='mpl', style={'backgroundcolor': '#EEEEEE'})
