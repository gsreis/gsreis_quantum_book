# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.visualization import plot_bloch_multivector
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.circuit.library import *
from qiskit.visualization import plot_bloch_multivector
from qiskit.visualization import plot_bloch_vector
from qiskit_aer import Aer
from qiskit.visualization import plot_bloch_multivector
import math
from qiskit import qasm3
from qiskit.quantum_info import state_fidelity
from qiskit.quantum_info import DensityMatrix
from qiskit.visualization import plot_state_qsphere
from qiskit import transpile
from qiskit.visualization import plot_state_city, plot_histogram
from pylatexenc import *
from qiskit.quantum_info import Operator
from qiskit.quantum_info import Statevector
from qiskit import *
from qiskit.circuit import *
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit.circuit.library import *
from qiskit.visualization import plot_bloch_multivector
from qiskit.visualization import plot_bloch_vector
from qiskit_aer import Aer
from qiskit.visualization import plot_bloch_multivector
import math
from qiskit import qasm3
from qiskit.quantum_info import state_fidelity
from qiskit.quantum_info import DensityMatrix
from qiskit import transpile
from qiskit.providers.basic_provider import BasicProvider

# %%
# Hadamard é reversível, sempre volta para zero quando reaplicado
qc = QuantumCircuit(2)
qc.h([0])
qc.h(1)
qc.barrier(0,1)
qc.h([0,1])
qc.draw(output='mpl',style={'backgroundcolor': '#EEEEEE'})

# %%
qc.measure_all()
backend = BasicProvider().get_backend('basic_simulator')
result = backend.run(qc, shots=1024).result()
counts = result.get_counts()
print(counts)

plot_histogram(counts)
# Out:
# {'00': 1024}

# %%
matrix = Statevector.from_instruction(qc)
plot_bloch_multivector(matrix, figsize=[3,3])

# %%
# começando em 0 hadamard com rotação
qc = QuantumCircuit(2)
angulo = math.pi + math.pi / 4
qc.h([0,1])
qc.barrier(0,1)
qc.rz(angulo, 0)
qc.rz(angulo, 1)
qc.barrier(0,1)
#qc.h([0,1])
qc.draw(output='mpl',style={'backgroundcolor': '#EEEEEE'})

# %%
qc.measure_all()
backend = BasicProvider().get_backend('basic_simulator')
result = backend.run(qc, shots=1024).result()
counts = result.get_counts()
print(counts)

plot_histogram(counts)
# Out:
# {'11': 728, '01': 130, '10': 133, '00': 33}

# %%
matrix = Statevector.from_instruction(qc)
plot_bloch_multivector(matrix, figsize=[3,3])

# %%
# começando em 1 hadamard com rotação
qc = QuantumCircuit(2)
angulo = math.pi
qc.x([0,1])
qc.h([0,1])
qc.barrier(0,1)
qc.rz(angulo, 0)
qc.rz(angulo, 1)
qc.barrier(0,1)
#qc.h([0,1])
qc.draw(output='mpl',style={'backgroundcolor': '#EEEEEE'})

# %%
qc.measure_all()
backend = BasicProvider().get_backend('basic_simulator')
result = backend.run(qc, shots=1024).result()
counts = result.get_counts()
print(counts)

plot_histogram(counts)
# Out:
# {'00': 1024}

# %%
matrix = Statevector.from_instruction(qc)
plot_bloch_multivector(matrix, figsize=[3,3])

# %%
# começando em 0 hadamard com rotação
qc = QuantumCircuit(2)
angulo1 = math.pi / 2 + math.pi / 4
angulo2 = math.pi / 8
#qc.x([0,1])
qc.h([0,1])
qc.barrier(0,1)
qc.rz(angulo1, 0)
qc.rz(angulo2, 1)
qc.barrier(0,1)
#qc.h([0,1])
qc.draw(output='mpl',style={'backgroundcolor': '#EEEEEE'})

# %%
qc.measure_all()
backend = BasicProvider().get_backend('basic_simulator')
result = backend.run(qc, shots=1024).result()
counts = result.get_counts()
print(counts)

plot_histogram(counts)
# Out:
# {'01': 834, '00': 144, '11': 40, '10': 6}

# %%
matrix = Statevector.from_instruction(qc)
plot_bloch_multivector(matrix, figsize=[3,3])

# %%
qc = QuantumCircuit(2)
qc.x([0,1])
qc.h([0,1])
qc.barrier(0,1)
qc.crz(math.pi /2, 0,1)
qc.barrier(0,1)
qc.h([0,1])
qc.draw(output='mpl',style={'backgroundcolor': '#EEEEEE'})

# %%
qc = QuantumCircuit(2)
qc.h([0,1])
qc.barrier(0,1)
qc.crz(math.pi /2, 0,1)
qc.barrier(0,1)
qc.h([0,1])
qc.draw(output='mpl',style={'backgroundcolor': '#EEEEEE'})

# %%
qc.measure_all()
backend = BasicProvider().get_backend('basic_simulator')
result = backend.run(qc, shots=1024).result()
counts = result.get_counts()
print(counts)

plot_histogram(counts)
# Out:
# {'11': 719, '01': 142, '00': 136, '10': 27}

# %%
matrix = Statevector.from_instruction(qc)
plot_bloch_multivector(matrix, figsize=[3,3])

# %%
qc = QuantumCircuit(2)
qc.h([0,1])
qc.barrier(0,1)
qc.rz(3 * math.pi /2, 0)
qc.rz(3 *math.pi /2, 1)
qc.barrier(0,1)
qc.crz(math.pi / 2, 0 ,1)
qc.h([0,1])
qc.draw(output='mpl',style={'backgroundcolor': '#EEEEEE'})

# %%
qc.measure_all()
backend = BasicProvider().get_backend('basic_simulator')
result = backend.run(qc, shots=1024).result()
counts = result.get_counts()
print(counts)

plot_histogram(counts)
# Out:
# {'00': 400, '01': 379, '11': 125, '10': 120}

# %%
matrix = Statevector.from_instruction(qc)
plot_bloch_multivector(matrix, figsize=[3,3])

# %%
qc = QuantumCircuit(2)
#qc.x([0,1])
qc.h([0,1])
qc.barrier(0,1)
qc.rz(math.pi /3, 0)
qc.rz(4 * math.pi /3, 1)
qc.barrier(0,1)
#qc.crz(math.pi / 3, 0 ,1)
#qc.h([0,1])
qc.draw(output='mpl',style={'backgroundcolor': '#EEEEEE'})

# %%
qc.measure_all()
backend = BasicProvider().get_backend('basic_simulator')
result = backend.run(qc, shots=1024).result()
counts = result.get_counts()
print(counts)

plot_histogram(counts)
# Out:
# {'10': 232, '11': 260, '00': 262, '01': 270}

# %%
matrix = Statevector.from_instruction(qc)
plot_bloch_multivector(matrix, figsize=[3,3])

# %% [markdown]
# ## END AQUI

# %%
qc = QuantumCircuit(2,2)
qc.x(1)
qc.h(1)
qc.barrier(0,1)
qc.h(0)
qc.cx(0,1)
#qc.crz(math.pi / 2, 0, 1)
#qc.crz(math.pi / 2, 0, 1)
qc.h(0)
qc.barrier(0,1)
qc.draw(output='mpl',style={'backgroundcolor': '#EEEEEE'})

# %%
qc.measure([0,1],[0,1])
backend = BasicProvider().get_backend('basic_simulator')
result = backend.run(qc, shots=1024).result()
counts = result.get_counts()
print(counts)

plot_histogram(counts)
# Out:
# {'11': 524, '01': 500}

# %%
qc = QuantumCircuit(2)
qc.x(1)
qc.h(0)
qc.cs(0,1)
qc.draw(output='mpl',style={'backgroundcolor': '#EEEEEE'})
